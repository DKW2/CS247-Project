# %% [markdown]
# We combine the results we found from data augmentation and data sampling to train a final model

# %%
# Combine our results from sampling and data augmentation!
# !python3.10 -m emg2qwerty.train \
      user="single_user" \
      trainer.accelerator=gpu trainer.devices=1 \
      logspec.n_fft=64 \
      logspec.hop_length=24 \
      module.in_features=528 \
      specaug.time_mask_param=15 \
      temporal_jitter.max_offset=200 \
      +validate=False \
      --multirun
# Out:
# [2025-03-12 15:03:37,721][HYDRA] Submitit 'local' sweep output dir : logs/2025-03-12/15-03-37
# [2025-03-12 15:03:37,722][HYDRA] 	#0 : user=single_user trainer.accelerator=gpu trainer.devices=1 logspec.n_fft=64 logspec.hop_length=24 module.in_features=528 specaug.time_mask_param=15 temporal_jitter.max_offset=200 +validate=False

# %%
# !python3.10 -m emg2qwerty.train \
  user="single_user" \
  checkpoint="logs/2025-03-10/20-26-04/best.ckpt" \
  train=False trainer.accelerator=gpu \
  logspec.n_fft=64 \
  logspec.hop_length=24 \
  module.in_features=528 \
  specaug.time_mask_param=15 \
  temporal_jitter.max_offset=200 \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 \
  +validate=False
# Out:
# [2025-03-10 23:32:41,283][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...
